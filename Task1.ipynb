# %% [markdown]
# #                                House Prices - Advanced Regression Techniques

# %% [markdown]
# ![0_XMbwmj-4r80bBuIg.jpg](attachment:bd9d5495-eb6f-465b-9721-87879eb4f39c.jpg)

# %% [markdown]
# **Step 1 : Business Problem Understanding**

# %% [markdown]
# * Implement a linear regression model to predict the prices of houses based on their square footage and the number of bedrooms and bathrooms.

# %% [markdown]
# # Step2 :Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# to visualise al the columns in the dataframe
#pd.pandas.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/train.csv")
df_test = pd.read_csv("/kaggle/input/house-prices-advanced-regression-techniques/test.csv")
dataset = pd.concat([df_train, df_test], axis=0)

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal   208500.0
# 1   2007        WD         Normal   181500.0
# 2   2008        WD         Normal   223500.0
# 3   2006        WD        Abnorml   140000.0
# 4   2008        WD         Normal   250000.0
#
# [5 rows x 81 columns]

# %%
## print shape of dataset with rows and columns
print(dataset.shape)
# Out:
# (2919, 81)

# %% [markdown]
# # Step 3 : Data Preprocessing

# %% [markdown]
# *Missing Values*

# %%
# Checking for missing values in the 'GrLivArea' column
missing_values = dataset['GrLivArea'].isnull().sum()
print("Missing values in the 'GrLivArea' column:", missing_values)
# Out:
# Missing values in the 'GrLivArea' column: 0

# %%
# Checking for missing values in the 'BedroomAbvGr' column
missing_values = dataset['BedroomAbvGr'].isnull().sum()
print("Missing values in the 'BedroomAbvGr' column:", missing_values)
# Out:
# Missing values in the 'BedroomAbvGr' column: 0

# %%
# Checking for missing values in the 'FullBath' column
missing_values = dataset['FullBath'].isnull().sum()
print("Missing values in the 'FullBath' column:", missing_values)
# Out:
# Missing values in the 'FullBath' column: 0

# %%
# Checking for missing values in the 'SalePrice' column
missing_values = dataset['SalePrice'].isnull().sum()
print("Missing values in the 'SalePrice' column:", missing_values)
# Out:
# Missing values in the 'SalePrice' column: 1459

# %%
dataset = dataset.dropna(subset=['SalePrice'])

# %%
# Checking for missing values in the 'SalePrice' column
missing_values = dataset['SalePrice'].isnull().sum()
print("Missing values in the 'SalePrice' column:", missing_values)
# Out:
# Missing values in the 'SalePrice' column: 0

# %% [markdown]
# # There are no missing values in the columns where we have to do operations

# %%
# Select relevant features (square footage, number of bedrooms, number of bathrooms) and the target variable (house prices)
X = dataset[['GrLivArea', 'BedroomAbvGr', 'FullBath']]
y = dataset['SalePrice']

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, random_state = 0)

# %% [markdown]
# # Step 4 : Modelling

# %% [markdown]
# **Implementing LinearRegression Model**

# %%
# Create a linear regression model
model = LinearRegression()

# %%
# Train the model on the training set
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 5 : Evaluation

# %% [markdown]
# * Prediction

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred
# Out:
# array([300775.43672347, 166148.29734725, 125635.67980201, 216821.75334224,
#        113643.94500862, 134068.16842717, 184525.55712859, 144217.46704943,
#        512629.41807336, 173403.95568525, 200412.36738208, 179874.24614099,
#        240595.0198112 ,  92901.48482546, 140550.18723441, 137627.4145954 ,
#        234113.00100396, 102624.51303632, 128336.5209717 , 164954.06305684,
#        148004.32033874, 143256.89257984, 111813.23718899, 186362.12912398,
#        201048.8409113 , 155879.23672671, 196301.22462841, 119705.55758021,
#        209805.43047682, 155026.69590391, 190245.47623257, 218124.02127944,
#        122184.46728057, 235835.67517681, 247401.1395588 , 182580.95148642,
#        222991.39956062,  90956.87918329, 224600.17591093, 309628.52010828,
#        231514.32930532, 142596.96234762, 167888.37552335, 224714.07373347,
#        300223.72866204, 129086.70379946, 112785.54001008,  92253.28294474,
#        208184.92577501, 124129.07292274, 314598.0678605 , 111591.30571966,
#        198467.7617399 , 108788.29507895, 231958.19224397,  89876.54271542,
#        209055.05912506, 220932.89609591, 116776.92076546, 108896.32872573,
#        109538.66643071, 108890.46454998, 157187.36883965, 120125.96381586,
#        207752.79118786, 155344.93266852, 123913.00562917, 209157.2285961 ,
#        161406.35671611, 213586.60811437, 181068.4804314 , 140010.01900047,
#        125641.54397776, 207650.62171682,  99383.5036327 , 204187.68084388,
#        103596.81585741, 124669.24115668, 264356.55792865, 167024.10634905,
#        124777.27480347,  89012.27354112, 141192.52493938, 102624.51303632,
#        390449.22773268, 170805.28398661, 126824.04991667, 202140.90573067,
#        157301.07813819, 112347.54124718, 208076.89212822, 196409.25827519,
#        188198.70111936, 227414.91490315, 190257.20458407, 159023.94083504,
#        186686.23006434, 179226.04426026,  89012.27354112, 196301.22462841,
#        213694.64176116, 236711.48417861, 140436.28941187, 149727.18303558,
#        101442.00709741, 259495.04382322, 198786.18702851, 126397.77950528,
#        186686.23006434, 142056.79411368,  98633.13228094, 106837.82526102,
#        213688.77758541, 116452.81982509, 183229.15336714, 193600.38345873,
#        284780.7813472 , 108026.19537568, 229785.79095672, 238002.2122883 ,
#        112347.54124718, 204733.71325357, 102408.44574274, 212068.2728836 ,
#        197921.72933022, 214024.60687727, 255503.66306785, 194902.65139592,
#        185714.11576725, 190899.54228904, 199548.09820778, 188312.5989419 ,
#        184399.93095455, 181932.7496057 ,  89012.27354112, 207860.82483465,
#        187226.39829827, 172101.68774805, 120996.09716591, 199542.23403203,
#        120125.96381586, 139469.85076654, 270412.30632449, 138719.29089078,
#        184844.1709412 , 188522.80205972])

# %%
# Evaluate the model
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Root Mean Squared Error: 48454.094080902054

# %% [markdown]
# # Predict the New Data

# %%
# Example: Predict house price for a new data point
new_data_point = pd.DataFrame([[2000, 3, 2]], columns=['GrLivArea', 'BedroomAbvGr', 'FullBath'])
predicted_price = model.predict(new_data_point)
print(f"Predicted Price for the new data point: ${predicted_price[0]}")
# Out:
# Predicted Price for the new data point: $242431.5918065828

# %%
# Example 2: Predict house price for a new data point
new_data_point = pd.DataFrame([[3000, 5, 4]], columns=['GrLivArea', 'BedroomAbvGr', 'FullBath'])
predicted_price = model.predict(new_data_point)
print(f"Predicted Price for the new data point: ${predicted_price[0]}")
# Out:
# Predicted Price for the new data point: $355878.27223674697

# %%
# Example 2: Predict house price for a new data point
new_data_point = pd.DataFrame([[3500, 6, 5]], columns=['GrLivArea', 'BedroomAbvGr', 'FullBath'])
predicted_price = model.predict(new_data_point)
print(f"Predicted Price for the new data point: ${predicted_price[0]}")
# Out:
# Predicted Price for the new data point: $412601.612451829

# %%
# Example 2: Predict house price for a new data point
new_data_point = pd.DataFrame([[2000, 3, 2]], columns=['GrLivArea', 'BedroomAbvGr', 'FullBath'])
predicted_price = model.predict(new_data_point)
print(f"Predicted Price for the new data point: ${predicted_price[0]}")
# Out:
# Predicted Price for the new data point: $242431.5918065828

# %% [markdown]
# # Model is working very well

# %% [markdown]
# # Visualization : Actual vs Predicted prices

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle="--", color='red', linewidth=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Prices vs. Predicted Prices')
plt.show()

# %%
# Residual plot
residuals = y_test - y_pred
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_pred, y=residuals)
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)
plt.xlabel('Predicted Prices')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
# Distribution of residuals
plt.figure(figsize=(10, 6))
sns.histplot(residuals, bins=30, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
